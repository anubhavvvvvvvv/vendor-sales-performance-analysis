# %%
import pandas as pd
import os
import logging

# %%
print("Hello VS Code!")
# Out:
# Hello VS Code!

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Python314\python.exe
# 3.14.0 (tags/v3.14.0:ebf955d, Oct  7 2025, 10:15:03) [MSC v.1944 64 bit (AMD64)]

# %%
# %pip install SQLAlchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: SQLAlchemy in C:\Users\ASUS\AppData\Roaming\Python\Python314\site-packages (2.0.51)
# Requirement already satisfied: greenlet>=1 in C:\Users\ASUS\AppData\Roaming\Python\Python314\site-packages (from SQLAlchemy) (3.5.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\ASUS\AppData\Roaming\Python\Python314\site-packages (from SQLAlchemy) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sqlalchemy import create_engine

engine = create_engine("sqlite:///inventory.db")

print("✅ SQLAlchemy is working!")
# Out:
# ✅ SQLAlchemy is working!

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\ASUS\Downloads\data\data

# %%
# Out:
# Processing begin_inventory.csv
# Inserted 10,000 rows into begin_inventory
# Inserted 20,000 rows into begin_inventory
# Inserted 30,000 rows into begin_inventory
# Inserted 40,000 rows into begin_inventory
# Inserted 50,000 rows into begin_inventory
# Inserted 60,000 rows into begin_inventory
# Inserted 70,000 rows into begin_inventory
# Inserted 80,000 rows into begin_inventory
# Inserted 90,000 rows into begin_inventory
# Inserted 100,000 rows into begin_inventory
# Inserted 110,000 rows into begin_inventory
# Inserted 120,000 rows into begin_inventory
# Inserted 130,000 rows into begin_inventory
# Inserted 140,000 rows into begin_inventory
# Inserted 150,000 rows into begin_inventory
# Inserted 160,000 rows into begin_inventory
# Inserted 170,000 rows into begin_inventory
# Inserted 180,000 rows into begin_inventory
# Inserted 190,000 rows into begin_inventory
# Inserted 200,000 rows into begin_inventory
# Inserted 206,529 rows into begin_inventory
# Finished begin_inventory
#
# Processing end_inventory.csv
# Inserted 10,000 rows into end_inventory
# Inserted 20,000 rows into end_inventory
# Inserted 30,000 rows into end_inventory
# Inserted 40,000 rows into end_inventory
# Inserted 50,000 rows into end_inventory
# Inserted 60,000 rows into end_inventory
# Inserted 70,000 rows into end_inventory
# Inserted 80,000 rows into end_inventory
# Inserted 90,000 rows into end_inventory
# Inserted 100,000 rows into end_inventory
# Inserted 110,000 rows into end_inventory
# Inserted 120,000 rows into end_inventory
# Inserted 130,000 rows into end_inventory
# Inserted 140,000 rows into end_inventory
# Inserted 150,000 rows into end_inventory
# Inserted 160,000 rows into end_inventory
# Inserted 170,000 rows into end_inventory
# Inserted 180,000 rows into end_inventory
# Inserted 190,000 rows into end_inventory
# Inserted 200,000 rows into end_inventory
# Inserted 210,000 rows into end_inventory
# Inserted 220,000 rows into end_inventory
# Inserted 224,489 rows into end_inventory
# Finished end_inventory
#
# Processing purchases.csv
# Inserted 10,000 rows into purchases
# Inserted 20,000 rows into purchases
# Inserted 30,000 rows into purchases
# Inserted 40,000 rows into purchases
# Inserted 50,000 rows into purchases
# Inserted 60,000 rows into purchases
# Inserted 70,000 rows into purchases
# Inserted 80,000 rows into purchases
# Inserted 90,000 rows into purchases
# Inserted 100,000 rows into purchases
# Inserted 110,000 rows into purchases
# Inserted 120,000 rows into purchases
# Inserted 130,000 rows into purchases
# Inserted 140,000 rows into purchases
# Inserted 150,000 rows into purchases
# Inserted 160,000 rows into purchases
# Inserted 170,000 rows into purchases
# Inserted 180,000 rows into purchases
# Inserted 190,000 rows into purchases
# Inserted 200,000 rows into purchases
# Inserted 210,000 rows into purchases
# Inserted 220,000 rows into purchases
# Inserted 230,000 rows into purchases
# Inserted 240,000 rows into purchases
# Inserted 250,000 rows into purchases
# Inserted 260,000 rows into purchases
# Inserted 270,000 rows into purchases
# Inserted 280,000 rows into purchases
# Inserted 290,000 rows into purchases
# Inserted 300,000 rows into purchases
# Inserted 310,000 rows into purchases
# Inserted 320,000 rows into purchases
# Inserted 330,000 rows into purchases
# Inserted 340,000 rows into purchases
# Inserted 350,000 rows into purchases
# Inserted 360,000 rows into purchases
# Inserted 370,000 rows into purchases
# Inserted 380,000 rows into purchases
# Inserted 390,000 rows into purchases
# Inserted 400,000 rows into purchases
# Inserted 410,000 rows into purchases
# Inserted 420,000 rows into purchases
# Inserted 430,000 rows into purchases
# Inserted 440,000 rows into purchases
# Inserted 450,000 rows into purchases
# Inserted 460,000 rows into purchases
# Inserted 470,000 rows into purchases
# Inserted 480,000 rows into purchases
# Inserted 490,000 rows into purchases
# Inserted 500,000 rows into purchases
# Inserted 510,000 rows into purchases
# Inserted 520,000 rows into purchases
# Inserted 530,000 rows into purchases
# Inserted 540,000 rows into purchases
# Inserted 550,000 rows into purchases
# Inserted 560,000 rows into purchases
# Inserted 570,000 rows into purchases
# Inserted 580,000 rows into purchases
# Inserted 590,000 rows into purchases
# Inserted 600,000 rows into purchases
# Inserted 610,000 rows into purchases
# Inserted 620,000 rows into purchases
# Inserted 630,000 rows into purchases
# Inserted 640,000 rows into purchases
# Inserted 650,000 rows into purchases
# Inserted 660,000 rows into purchases
# Inserted 670,000 rows into purchases
# Inserted 680,000 rows into purchases
# Inserted 690,000 rows into purchases
# Inserted 700,000 rows into purchases
# Inserted 710,000 rows into purchases
# Inserted 720,000 rows into purchases
# Inserted 730,000 rows into purchases
# Inserted 740,000 rows into purchases
# Inserted 750,000 rows into purchases
# Inserted 760,000 rows into purchases
# Inserted 770,000 rows into purchases
# Inserted 780,000 rows into purchases
# Inserted 790,000 rows into purchases
# Inserted 800,000 rows into purchases
# Inserted 810,000 rows into purchases
# Inserted 820,000 rows into purchases
# Inserted 830,000 rows into purchases
# Inserted 840,000 rows into purchases
# Inserted 850,000 rows into purchases
# Inserted 860,000 rows into purchases
# Inserted 870,000 rows into purchases
# Inserted 880,000 rows into purchases
# Inserted 890,000 rows into purchases
# Inserted 900,000 rows into purchases
# Inserted 910,000 rows into purchases
# Inserted 920,000 rows into purchases
# Inserted 930,000 rows into purchases
# Inserted 940,000 rows into purchases
# Inserted 950,000 rows into purchases
# Inserted 960,000 rows into purchases
# Inserted 970,000 rows into purchases
# Inserted 980,000 rows into purchases
# Inserted 990,000 rows into purchases
# Inserted 1,000,000 rows into purchases
# Inserted 1,010,000 rows into purchases
# Inserted 1,020,000 rows into purchases
# Inserted 1,030,000 rows into purchases
# Inserted 1,040,000 rows into purchases
# Inserted 1,050,000 rows into purchases
# Inserted 1,060,000 rows into purchases
# Inserted 1,070,000 rows into purchases
# Inserted 1,080,000 rows into purchases
# Inserted 1,090,000 rows into purchases
# Inserted 1,100,000 rows into purchases
# Inserted 1,110,000 rows into purchases
# Inserted 1,120,000 rows into purchases
# Inserted 1,130,000 rows into purchases
# Inserted 1,140,000 rows into purchases
# Inserted 1,150,000 rows into purchases
# Inserted 1,160,000 rows into purchases
# Inserted 1,170,000 rows into purchases
# Inserted 1,180,000 rows into purchases
# Inserted 1,190,000 rows into purchases
# Inserted 1,200,000 rows into purchases
# Inserted 1,210,000 rows into purchases
# Inserted 1,220,000 rows into purchases
# Inserted 1,230,000 rows into purchases
# Inserted 1,240,000 rows into purchases
# Inserted 1,250,000 rows into purchases
# Inserted 1,260,000 rows into purchases
# Inserted 1,270,000 rows into purchases
# Inserted 1,280,000 rows into purchases
# Inserted 1,290,000 rows into purchases
# Inserted 1,300,000 rows into purchases
# Inserted 1,310,000 rows into purchases
# Inserted 1,320,000 rows into purchases
# Inserted 1,330,000 rows into purchases
# Inserted 1,340,000 rows into purchases
# Inserted 1,350,000 rows into purchases
# Inserted 1,360,000 rows into purchases
# Inserted 1,370,000 rows into purchases
# Inserted 1,380,000 rows into purchases
# Inserted 1,390,000 rows into purchases
# Inserted 1,400,000 rows into purchases
# Inserted 1,410,000 rows into purchases
# Inserted 1,420,000 rows into purchases
# Inserted 1,430,000 rows into purchases
# Inserted 1,440,000 rows into purchases
# Inserted 1,450,000 rows into purchases
# Inserted 1,460,000 rows into purchases
# Inserted 1,470,000 rows into purchases
# Inserted 1,480,000 rows into purchases
# Inserted 1,490,000 rows into purchases
# Inserted 1,500,000 rows into purchases
# Inserted 1,510,000 rows into purchases
# Inserted 1,520,000 rows into purchases
# Inserted 1,530,000 rows into purchases
# Inserted 1,540,000 rows into purchases
# Inserted 1,550,000 rows into purchases
# Inserted 1,560,000 rows into purchases
# Inserted 1,570,000 rows into purchases
# Inserted 1,580,000 rows into purchases
# Inserted 1,590,000 rows into purchases
# Inserted 1,600,000 rows into purchases
# Inserted 1,610,000 rows into purchases
# Inserted 1,620,000 rows into purchases
# Inserted 1,630,000 rows into purchases
# Inserted 1,640,000 rows into purchases
# Inserted 1,650,000 rows into purchases
# Inserted 1,660,000 rows into purchases
# Inserted 1,670,000 rows into purchases
# Inserted 1,680,000 rows into purchases
# Inserted 1,690,000 rows into purchases
# Inserted 1,700,000 rows into purchases
# Inserted 1,710,000 rows into purchases
# Inserted 1,720,000 rows into purchases
# Inserted 1,730,000 rows into purchases
# Inserted 1,740,000 rows into purchases
# Inserted 1,750,000 rows into purchases
# Inserted 1,760,000 rows into purchases
# Inserted 1,770,000 rows into purchases
# Inserted 1,780,000 rows into purchases
# Inserted 1,790,000 rows into purchases
# Inserted 1,800,000 rows into purchases
# Inserted 1,810,000 rows into purchases
# Inserted 1,820,000 rows into purchases
# Inserted 1,830,000 rows into purchases
# Inserted 1,840,000 rows into purchases
# Inserted 1,850,000 rows into purchases
# Inserted 1,860,000 rows into purchases
# Inserted 1,870,000 rows into purchases
# Inserted 1,880,000 rows into purchases
# Inserted 1,890,000 rows into purchases
# Inserted 1,900,000 rows into purchases
# Inserted 1,910,000 rows into purchases
# Inserted 1,920,000 rows into purchases
# Inserted 1,930,000 rows into purchases
# Inserted 1,940,000 rows into purchases
# Inserted 1,950,000 rows into purchases
# Inserted 1,960,000 rows into purchases
# Inserted 1,970,000 rows into purchases
# Inserted 1,980,000 rows into purchases
# Inserted 1,990,000 rows into purchases
# Inserted 2,000,000 rows into purchases
# Inserted 2,010,000 rows into purchases
# Inserted 2,020,000 rows into purchases
# Inserted 2,030,000 rows into purchases
# Inserted 2,040,000 rows into purchases
# Inserted 2,050,000 rows into purchases
# Inserted 2,060,000 rows into purchases
# Inserted 2,070,000 rows into purchases
# Inserted 2,080,000 rows into purchases
# Inserted 2,090,000 rows into purchases
# Inserted 2,100,000 rows into purchases
# Inserted 2,110,000 rows into purchases
# Inserted 2,120,000 rows into purchases
# Inserted 2,130,000 rows into purchases
# Inserted 2,140,000 rows into purchases
# Inserted 2,150,000 rows into purchases
# Inserted 2,160,000 rows into purchases
# Inserted 2,170,000 rows into purchases
# Inserted 2,180,000 rows into purchases
# Inserted 2,190,000 rows into purchases
# Inserted 2,200,000 rows into purchases
# Inserted 2,210,000 rows into purchases
# Inserted 2,220,000 rows into purchases
# Inserted 2,230,000 rows into purchases
# Inserted 2,240,000 rows into purchases
# Inserted 2,250,000 rows into purchases
# Inserted 2,260,000 rows into purchases
# Inserted 2,270,000 rows into purchases
# Inserted 2,280,000 rows into purchases
# Inserted 2,290,000 rows into purchases
# Inserted 2,300,000 rows into purchases
# Inserted 2,310,000 rows into purchases
# Inserted 2,320,000 rows into purchases
# Inserted 2,330,000 rows into purchases
# Inserted 2,340,000 rows into purchases
# Inserted 2,350,000 rows into purchases
# Inserted 2,360,000 rows into purchases
# Inserted 2,370,000 rows into purchases
# Inserted 2,372,474 rows into purchases
# Finished purchases
#
# Processing purchase_prices.csv
# Inserted 10,000 rows into purchase_prices
# Inserted 12,261 rows into purchase_prices
# Finished purchase_prices
#
# Processing sales.csv
# Inserted 10,000 rows into sales
# Inserted 20,000 rows into sales
# Inserted 30,000 rows into sales
# Inserted 40,000 rows into sales
# Inserted 50,000 rows into sales
# Inserted 60,000 rows into sales
# Inserted 70,000 rows into sales
# Inserted 80,000 rows into sales
# Inserted 90,000 rows into sales
# Inserted 100,000 rows into sales
# Inserted 110,000 rows into sales
# Inserted 120,000 rows into sales
# Inserted 130,000 rows into sales
# Inserted 140,000 rows into sales
# Inserted 150,000 rows into sales
# Inserted 160,000 rows into sales
# Inserted 170,000 rows into sales
# Inserted 180,000 rows into sales
# Inserted 190,000 rows into sales
# Inserted 200,000 rows into sales
# Inserted 210,000 rows into sales
# Inserted 220,000 rows into sales
# Inserted 230,000 rows into sales
# Inserted 240,000 rows into sales
# Inserted 250,000 rows into sales
# Inserted 260,000 rows into sales
# Inserted 270,000 rows into sales
# Inserted 280,000 rows into sales
# Inserted 290,000 rows into sales
# Inserted 300,000 rows into sales
# Inserted 310,000 rows into sales
# Inserted 320,000 rows into sales
# Inserted 330,000 rows into sales
# Inserted 340,000 rows into sales
# Inserted 350,000 rows into sales
# Inserted 360,000 rows into sales
# Inserted 370,000 rows into sales
# Inserted 380,000 rows into sales
# Inserted 390,000 rows into sales
# Inserted 400,000 rows into sales
# Inserted 410,000 rows into sales
# Inserted 420,000 rows into sales
# Inserted 430,000 rows into sales
# Inserted 440,000 rows into sales
# Inserted 450,000 rows into sales
# Inserted 460,000 rows into sales
# Inserted 470,000 rows into sales
# Inserted 480,000 rows into sales
# Inserted 490,000 rows into sales
# Inserted 500,000 rows into sales
# Inserted 510,000 rows into sales
# Inserted 520,000 rows into sales
# Inserted 530,000 rows into sales
# Inserted 540,000 rows into sales
# Inserted 550,000 rows into sales
# Inserted 560,000 rows into sales
# Inserted 570,000 rows into sales
# Inserted 580,000 rows into sales
# Inserted 590,000 rows into sales
# Inserted 600,000 rows into sales
# Inserted 610,000 rows into sales
# Inserted 620,000 rows into sales
# Inserted 630,000 rows into sales
# Inserted 640,000 rows into sales
# Inserted 650,000 rows into sales
# Inserted 660,000 rows into sales
# Inserted 670,000 rows into sales
# Inserted 680,000 rows into sales
# Inserted 690,000 rows into sales
# Inserted 700,000 rows into sales
# Inserted 710,000 rows into sales
# Inserted 720,000 rows into sales
# Inserted 730,000 rows into sales
# Inserted 740,000 rows into sales
# Inserted 750,000 rows into sales
# Inserted 760,000 rows into sales
# Inserted 770,000 rows into sales
# Inserted 780,000 rows into sales
# Inserted 790,000 rows into sales
# Inserted 800,000 rows into sales
# Inserted 810,000 rows into sales
# Inserted 820,000 rows into sales
# Inserted 830,000 rows into sales
# Inserted 840,000 rows into sales
# Inserted 850,000 rows into sales
# Inserted 860,000 rows into sales
# Inserted 870,000 rows into sales
# Inserted 880,000 rows into sales
# Inserted 890,000 rows into sales
# Inserted 900,000 rows into sales
# Inserted 910,000 rows into sales
# Inserted 920,000 rows into sales
# Inserted 930,000 rows into sales
# Inserted 940,000 rows into sales
# Inserted 950,000 rows into sales
# Inserted 960,000 rows into sales
# Inserted 970,000 rows into sales
# Inserted 980,000 rows into sales
# Inserted 990,000 rows into sales
# Inserted 1,000,000 rows into sales
# Inserted 1,010,000 rows into sales
# Inserted 1,020,000 rows into sales
# Inserted 1,030,000 rows into sales
# Inserted 1,040,000 rows into sales
# Inserted 1,050,000 rows into sales
# Inserted 1,060,000 rows into sales
# Inserted 1,070,000 rows into sales
# Inserted 1,080,000 rows into sales
# Inserted 1,090,000 rows into sales
# Inserted 1,100,000 rows into sales
# Inserted 1,110,000 rows into sales
# Inserted 1,120,000 rows into sales
# Inserted 1,130,000 rows into sales
# Inserted 1,140,000 rows into sales
# Inserted 1,150,000 rows into sales
# Inserted 1,160,000 rows into sales
# Inserted 1,170,000 rows into sales
# Inserted 1,180,000 rows into sales
# Inserted 1,190,000 rows into sales
# Inserted 1,200,000 rows into sales
# Inserted 1,210,000 rows into sales
# Inserted 1,220,000 rows into sales
# Inserted 1,230,000 rows into sales
# Inserted 1,240,000 rows into sales
# Inserted 1,250,000 rows into sales
# Inserted 1,260,000 rows into sales
# Inserted 1,270,000 rows into sales
# Inserted 1,280,000 rows into sales
# Inserted 1,290,000 rows into sales
# Inserted 1,300,000 rows into sales
# Inserted 1,310,000 rows into sales
# Inserted 1,320,000 rows into sales
# Inserted 1,330,000 rows into sales
# Inserted 1,340,000 rows into sales
# Inserted 1,350,000 rows into sales
# Inserted 1,360,000 rows into sales
# Inserted 1,370,000 rows into sales
# Inserted 1,380,000 rows into sales
# Inserted 1,390,000 rows into sales
# Inserted 1,400,000 rows into sales
# Inserted 1,410,000 rows into sales
# Inserted 1,420,000 rows into sales
# Inserted 1,430,000 rows into sales
# Inserted 1,440,000 rows into sales
# Inserted 1,450,000 rows into sales
# Inserted 1,460,000 rows into sales
# Inserted 1,470,000 rows into sales
# Inserted 1,480,000 rows into sales
# Inserted 1,490,000 rows into sales
# Inserted 1,500,000 rows into sales
# Inserted 1,510,000 rows into sales
# Inserted 1,520,000 rows into sales
# Inserted 1,530,000 rows into sales
# Inserted 1,540,000 rows into sales
# Inserted 1,550,000 rows into sales
# Inserted 1,560,000 rows into sales
# Inserted 1,570,000 rows into sales
# Inserted 1,580,000 rows into sales
# Inserted 1,590,000 rows into sales
# Inserted 1,600,000 rows into sales
# Inserted 1,610,000 rows into sales
# Inserted 1,620,000 rows into sales
# Inserted 1,630,000 rows into sales
# Inserted 1,640,000 rows into sales
# Inserted 1,650,000 rows into sales
# Inserted 1,660,000 rows into sales
# Inserted 1,670,000 rows into sales
# Inserted 1,680,000 rows into sales
# Inserted 1,690,000 rows into sales
# Inserted 1,700,000 rows into sales
# Inserted 1,710,000 rows into sales
# Inserted 1,720,000 rows into sales
# Inserted 1,730,000 rows into sales
# Inserted 1,740,000 rows into sales
# Inserted 1,750,000 rows into sales
# Inserted 1,760,000 rows into sales
# Inserted 1,770,000 rows into sales
# Inserted 1,780,000 rows into sales
# Inserted 1,790,000 rows into sales
# Inserted 1,800,000 rows into sales
# Inserted 1,810,000 rows into sales
# Inserted 1,820,000 rows into sales
# Inserted 1,830,000 rows into sales
# Inserted 1,840,000 rows into sales
# Inserted 1,850,000 rows into sales
# Inserted 1,860,000 rows into sales
# Inserted 1,870,000 rows into sales
# Inserted 1,880,000 rows into sales
# Inserted 1,890,000 rows into sales
# Inserted 1,900,000 rows into sales
# Inserted 1,910,000 rows into sales
# Inserted 1,920,000 rows into sales
# Inserted 1,930,000 rows into sales
# Inserted 1,940,000 rows into sales
# Inserted 1,950,000 rows into sales
# Inserted 1,960,000 rows into sales
# Inserted 1,970,000 rows into sales
# Inserted 1,980,000 rows into sales
# Inserted 1,990,000 rows into sales
# Inserted 2,000,000 rows into sales
# Inserted 2,010,000 rows into sales
# Inserted 2,020,000 rows into sales
# Inserted 2,030,000 rows into sales
# Inserted 2,040,000 rows into sales
# Inserted 2,050,000 rows into sales
# Inserted 2,060,000 rows into sales
# Inserted 2,070,000 rows into sales
# Inserted 2,080,000 rows into sales
# Inserted 2,090,000 rows into sales
# Inserted 2,100,000 rows into sales
# Inserted 2,110,000 rows into sales
# Inserted 2,120,000 rows into sales
# Inserted 2,130,000 rows into sales
# Inserted 2,140,000 rows into sales
# Inserted 2,150,000 rows into sales
# Inserted 2,160,000 rows into sales
# Inserted 2,170,000 rows into sales
# Inserted 2,180,000 rows into sales
# Inserted 2,190,000 rows into sales
# Inserted 2,200,000 rows into sales
# Inserted 2,210,000 rows into sales
# Inserted 2,220,000 rows into sales
# Inserted 2,230,000 rows into sales
# Inserted 2,240,000 rows into sales
# Inserted 2,250,000 rows into sales
# Inserted 2,260,000 rows into sales
# Inserted 2,270,000 rows into sales
# Inserted 2,280,000 rows into sales
# Inserted 2,290,000 rows into sales
# Inserted 2,300,000 rows into sales
# Inserted 2,310,000 rows into sales
# Inserted 2,320,000 rows into sales
# Inserted 2,330,000 rows into sales
# Inserted 2,340,000 rows into sales
# Inserted 2,350,000 rows into sales
# Inserted 2,360,000 rows into sales
# Inserted 2,370,000 rows into sales
# Inserted 2,380,000 rows into sales
# Inserted 2,390,000 rows into sales
# Inserted 2,400,000 rows into sales
# Inserted 2,410,000 rows into sales
# Inserted 2,420,000 rows into sales
# Inserted 2,430,000 rows into sales
# Inserted 2,440,000 rows into sales
# Inserted 2,450,000 rows into sales
# Inserted 2,460,000 rows into sales
# Inserted 2,470,000 rows into sales
# Inserted 2,480,000 rows into sales
# Inserted 2,490,000 rows into sales
# Inserted 2,500,000 rows into sales
# Inserted 2,510,000 rows into sales
# Inserted 2,520,000 rows into sales
# Inserted 2,530,000 rows into sales
# Inserted 2,540,000 rows into sales
# Inserted 2,550,000 rows into sales
# Inserted 2,560,000 rows into sales
# Inserted 2,570,000 rows into sales
# Inserted 2,580,000 rows into sales
# Inserted 2,590,000 rows into sales
# Inserted 2,600,000 rows into sales
# Inserted 2,610,000 rows into sales
# Inserted 2,620,000 rows into sales
# Inserted 2,630,000 rows into sales
# Inserted 2,640,000 rows into sales
# Inserted 2,650,000 rows into sales
# Inserted 2,660,000 rows into sales
# Inserted 2,670,000 rows into sales
# Inserted 2,680,000 rows into sales
# Inserted 2,690,000 rows into sales
# Inserted 2,700,000 rows into sales
# Inserted 2,710,000 rows into sales
# Inserted 2,720,000 rows into sales
# Inserted 2,730,000 rows into sales
# Inserted 2,740,000 rows into sales
# Inserted 2,750,000 rows into sales
# Inserted 2,760,000 rows into sales
# Inserted 2,770,000 rows into sales
# Inserted 2,780,000 rows into sales
# Inserted 2,790,000 rows into sales
# Inserted 2,800,000 rows into sales
# Inserted 2,810,000 rows into sales
# Inserted 2,820,000 rows into sales
# Inserted 2,830,000 rows into sales
# Inserted 2,840,000 rows into sales
# Inserted 2,850,000 rows into sales
# Inserted 2,860,000 rows into sales
# Inserted 2,870,000 rows into sales
# Inserted 2,880,000 rows into sales
# Inserted 2,890,000 rows into sales
# Inserted 2,900,000 rows into sales
# Inserted 2,910,000 rows into sales
# Inserted 2,920,000 rows into sales
# Inserted 2,930,000 rows into sales
# Inserted 2,940,000 rows into sales
# Inserted 2,950,000 rows into sales
# Inserted 2,960,000 rows into sales
# Inserted 2,970,000 rows into sales
# Inserted 2,980,000 rows into sales
# Inserted 2,990,000 rows into sales
# Inserted 3,000,000 rows into sales
# Inserted 3,010,000 rows into sales
# Inserted 3,020,000 rows into sales
# Inserted 3,030,000 rows into sales
# Inserted 3,040,000 rows into sales
# Inserted 3,050,000 rows into sales
# Inserted 3,060,000 rows into sales
# Inserted 3,070,000 rows into sales
# Inserted 3,080,000 rows into sales
# Inserted 3,090,000 rows into sales
# Inserted 3,100,000 rows into sales
# Inserted 3,110,000 rows into sales
# Inserted 3,120,000 rows into sales
# Inserted 3,130,000 rows into sales
# Inserted 3,140,000 rows into sales
# Inserted 3,150,000 rows into sales
# Inserted 3,160,000 rows into sales
# Inserted 3,170,000 rows into sales
# Inserted 3,180,000 rows into sales
# Inserted 3,190,000 rows into sales
# Inserted 3,200,000 rows into sales
# Inserted 3,210,000 rows into sales
# Inserted 3,220,000 rows into sales
# Inserted 3,230,000 rows into sales
# Inserted 3,240,000 rows into sales
# Inserted 3,250,000 rows into sales
# Inserted 3,260,000 rows into sales
# Inserted 3,270,000 rows into sales
# Inserted 3,280,000 rows into sales
# Inserted 3,290,000 rows into sales
# Inserted 3,300,000 rows into sales
# Inserted 3,310,000 rows into sales
# Inserted 3,320,000 rows into sales
# Inserted 3,330,000 rows into sales
# Inserted 3,340,000 rows into sales
# Inserted 3,350,000 rows into sales
# Inserted 3,360,000 rows into sales
# Inserted 3,370,000 rows into sales
# Inserted 3,380,000 rows into sales
# Inserted 3,390,000 rows into sales
# Inserted 3,400,000 rows into sales
# Inserted 3,410,000 rows into sales
# Inserted 3,420,000 rows into sales
# Inserted 3,430,000 rows into sales
# Inserted 3,440,000 rows into sales
# Inserted 3,450,000 rows into sales
# Inserted 3,460,000 rows into sales
# Inserted 3,470,000 rows into sales
# Inserted 3,480,000 rows into sales
# Inserted 3,490,000 rows into sales
# Inserted 3,500,000 rows into sales
# Inserted 3,510,000 rows into sales
# Inserted 3,520,000 rows into sales
# Inserted 3,530,000 rows into sales
# Inserted 3,540,000 rows into sales
# Inserted 3,550,000 rows into sales
# Inserted 3,560,000 rows into sales
# Inserted 3,570,000 rows into sales
# Inserted 3,580,000 rows into sales
# Inserted 3,590,000 rows into sales
# Inserted 3,600,000 rows into sales
# Inserted 3,610,000 rows into sales
# Inserted 3,620,000 rows into sales
# Inserted 3,630,000 rows into sales
# Inserted 3,640,000 rows into sales
# Inserted 3,650,000 rows into sales
# Inserted 3,660,000 rows into sales
# Inserted 3,670,000 rows into sales
# Inserted 3,680,000 rows into sales
# Inserted 3,690,000 rows into sales
# Inserted 3,700,000 rows into sales
# Inserted 3,710,000 rows into sales
# Inserted 3,720,000 rows into sales
# Inserted 3,730,000 rows into sales
# Inserted 3,740,000 rows into sales
# Inserted 3,750,000 rows into sales
# Inserted 3,760,000 rows into sales
# Inserted 3,770,000 rows into sales
# Inserted 3,780,000 rows into sales
# Inserted 3,790,000 rows into sales
# Inserted 3,800,000 rows into sales
# Inserted 3,810,000 rows into sales
# Inserted 3,820,000 rows into sales
# Inserted 3,830,000 rows into sales
# Inserted 3,840,000 rows into sales
# Inserted 3,850,000 rows into sales
# Inserted 3,860,000 rows into sales
# Inserted 3,870,000 rows into sales
# Inserted 3,880,000 rows into sales
# Inserted 3,890,000 rows into sales
# Inserted 3,900,000 rows into sales
# Inserted 3,910,000 rows into sales
# Inserted 3,920,000 rows into sales
# Inserted 3,930,000 rows into sales
# Inserted 3,940,000 rows into sales
# Inserted 3,950,000 rows into sales
# Inserted 3,960,000 rows into sales
# Inserted 3,970,000 rows into sales
# Inserted 3,980,000 rows into sales
# Inserted 3,990,000 rows into sales
# Inserted 4,000,000 rows into sales
# Inserted 4,010,000 rows into sales
# Inserted 4,020,000 rows into sales
# Inserted 4,030,000 rows into sales
# Inserted 4,040,000 rows into sales
# Inserted 4,050,000 rows into sales
# Inserted 4,060,000 rows into sales
# Inserted 4,070,000 rows into sales
# Inserted 4,080,000 rows into sales
# Inserted 4,090,000 rows into sales
# Inserted 4,100,000 rows into sales
# Inserted 4,110,000 rows into sales
# Inserted 4,120,000 rows into sales
# Inserted 4,130,000 rows into sales
# Inserted 4,140,000 rows into sales
# Inserted 4,150,000 rows into sales
# Inserted 4,160,000 rows into sales
# Inserted 4,170,000 rows into sales
# Inserted 4,180,000 rows into sales
# Inserted 4,190,000 rows into sales
# Inserted 4,200,000 rows into sales
# Inserted 4,210,000 rows into sales
# Inserted 4,220,000 rows into sales
# Inserted 4,230,000 rows into sales
# Inserted 4,240,000 rows into sales
# Inserted 4,250,000 rows into sales
# Inserted 4,260,000 rows into sales
# Inserted 4,270,000 rows into sales
# Inserted 4,280,000 rows into sales
# Inserted 4,290,000 rows into sales
# Inserted 4,300,000 rows into sales
# Inserted 4,310,000 rows into sales
# Inserted 4,320,000 rows into sales
# Inserted 4,330,000 rows into sales
# Inserted 4,340,000 rows into sales
# Inserted 4,350,000 rows into sales
# Inserted 4,360,000 rows into sales
# Inserted 4,370,000 rows into sales
# Inserted 4,380,000 rows into sales
# Inserted 4,390,000 rows into sales
# Inserted 4,400,000 rows into sales
# Inserted 4,410,000 rows into sales
# Inserted 4,420,000 rows into sales
# Inserted 4,430,000 rows into sales
# Inserted 4,440,000 rows into sales
# Inserted 4,450,000 rows into sales
# Inserted 4,460,000 rows into sales
# Inserted 4,470,000 rows into sales
# Inserted 4,480,000 rows into sales
# Inserted 4,490,000 rows into sales
# Inserted 4,500,000 rows into sales
# Inserted 4,510,000 rows into sales
# Inserted 4,520,000 rows into sales
# Inserted 4,530,000 rows into sales
# Inserted 4,540,000 rows into sales
# Inserted 4,550,000 rows into sales
# Inserted 4,560,000 rows into sales
# Inserted 4,570,000 rows into sales
# Inserted 4,580,000 rows into sales
# Inserted 4,590,000 rows into sales
# Inserted 4,600,000 rows into sales
# Inserted 4,610,000 rows into sales
# Inserted 4,620,000 rows into sales
# Inserted 4,630,000 rows into sales
# Inserted 4,640,000 rows into sales
# Inserted 4,650,000 rows into sales
# Inserted 4,660,000 rows into sales
# Inserted 4,670,000 rows into sales
# Inserted 4,680,000 rows into sales
# Inserted 4,690,000 rows into sales
# Inserted 4,700,000 rows into sales
# Inserted 4,710,000 rows into sales
# Inserted 4,720,000 rows into sales
# Inserted 4,730,000 rows into sales
# Inserted 4,740,000 rows into sales
# Inserted 4,750,000 rows into sales
# Inserted 4,760,000 rows into sales
# Inserted 4,770,000 rows into sales
# Inserted 4,780,000 rows into sales
# Inserted 4,790,000 rows into sales
# Inserted 4,800,000 rows into sales
# Inserted 4,810,000 rows into sales
# Inserted 4,820,000 rows into sales
# Inserted 4,830,000 rows into sales
# Inserted 4,840,000 rows into sales
# Inserted 4,850,000 rows into sales
# Inserted 4,860,000 rows into sales
# Inserted 4,870,000 rows into sales
# Inserted 4,880,000 rows into sales
# Inserted 4,890,000 rows into sales
# Inserted 4,900,000 rows into sales
# Inserted 4,910,000 rows into sales
# Inserted 4,920,000 rows into sales
# Inserted 4,930,000 rows into sales
# Inserted 4,940,000 rows into sales
# Inserted 4,950,000 rows into sales
# Inserted 4,960,000 rows into sales
# Inserted 4,970,000 rows into sales
# Inserted 4,980,000 rows into sales
# Inserted 4,990,000 rows into sales
# Inserted 5,000,000 rows into sales
# Inserted 5,010,000 rows into sales
# Inserted 5,020,000 rows into sales
# Inserted 5,030,000 rows into sales
# Inserted 5,040,000 rows into sales
# Inserted 5,050,000 rows into sales
# Inserted 5,060,000 rows into sales
# Inserted 5,070,000 rows into sales
# Inserted 5,080,000 rows into sales
# Inserted 5,090,000 rows into sales
# Inserted 5,100,000 rows into sales
# Inserted 5,110,000 rows into sales
# Inserted 5,120,000 rows into sales
# Inserted 5,130,000 rows into sales
# Inserted 5,140,000 rows into sales
# Inserted 5,150,000 rows into sales
# Inserted 5,160,000 rows into sales
# Inserted 5,170,000 rows into sales
# Inserted 5,180,000 rows into sales
# Inserted 5,190,000 rows into sales
# Inserted 5,200,000 rows into sales
# Inserted 5,210,000 rows into sales
# Inserted 5,220,000 rows into sales
# Inserted 5,230,000 rows into sales
# Inserted 5,240,000 rows into sales
# Inserted 5,250,000 rows into sales
# Inserted 5,260,000 rows into sales
# Inserted 5,270,000 rows into sales
# Inserted 5,280,000 rows into sales
# Inserted 5,290,000 rows into sales
# Inserted 5,300,000 rows into sales
# Inserted 5,310,000 rows into sales
# Inserted 5,320,000 rows into sales
# Inserted 5,330,000 rows into sales
# Inserted 5,340,000 rows into sales
# Inserted 5,350,000 rows into sales
# Inserted 5,360,000 rows into sales
# Inserted 5,370,000 rows into sales
# Inserted 5,380,000 rows into sales
# Inserted 5,390,000 rows into sales
# Inserted 5,400,000 rows into sales
# Inserted 5,410,000 rows into sales
# Inserted 5,420,000 rows into sales
# Inserted 5,430,000 rows into sales
# Inserted 5,440,000 rows into sales
# Inserted 5,450,000 rows into sales
# Inserted 5,460,000 rows into sales
# Inserted 5,470,000 rows into sales
# Inserted 5,480,000 rows into sales
# Inserted 5,490,000 rows into sales
# Inserted 5,500,000 rows into sales
# Inserted 5,510,000 rows into sales
# Inserted 5,520,000 rows into sales
# Inserted 5,530,000 rows into sales
# Inserted 5,540,000 rows into sales
# Inserted 5,550,000 rows into sales
# Inserted 5,560,000 rows into sales
# Inserted 5,570,000 rows into sales
# Inserted 5,580,000 rows into sales
# Inserted 5,590,000 rows into sales
# Inserted 5,600,000 rows into sales
# Inserted 5,610,000 rows into sales
# Inserted 5,620,000 rows into sales
# Inserted 5,630,000 rows into sales
# Inserted 5,640,000 rows into sales
# Inserted 5,650,000 rows into sales
# Inserted 5,660,000 rows into sales
# Inserted 5,670,000 rows into sales
# Inserted 5,680,000 rows into sales
# Inserted 5,690,000 rows into sales
# Inserted 5,700,000 rows into sales
# Inserted 5,710,000 rows into sales
# Inserted 5,720,000 rows into sales
# Inserted 5,730,000 rows into sales
# Inserted 5,740,000 rows into sales
# Inserted 5,750,000 rows into sales
# Inserted 5,760,000 rows into sales
# Inserted 5,770,000 rows into sales
# Inserted 5,780,000 rows into sales
# Inserted 5,790,000 rows into sales
# Inserted 5,800,000 rows into sales
# Inserted 5,810,000 rows into sales
# Inserted 5,820,000 rows into sales
# Inserted 5,830,000 rows into sales
# Inserted 5,840,000 rows into sales
# Inserted 5,850,000 rows into sales
# Inserted 5,860,000 rows into sales
# Inserted 5,870,000 rows into sales
# Inserted 5,880,000 rows into sales
# Inserted 5,890,000 rows into sales
# Inserted 5,900,000 rows into sales
# Inserted 5,910,000 rows into sales
# Inserted 5,920,000 rows into sales
# Inserted 5,930,000 rows into sales
# Inserted 5,940,000 rows into sales
# Inserted 5,950,000 rows into sales
# Inserted 5,960,000 rows into sales
# Inserted 5,970,000 rows into sales
# Inserted 5,980,000 rows into sales
# Inserted 5,990,000 rows into sales
# Inserted 6,000,000 rows into sales
# Inserted 6,010,000 rows into sales
# Inserted 6,020,000 rows into sales
# Inserted 6,030,000 rows into sales
# Inserted 6,040,000 rows into sales
# Inserted 6,050,000 rows into sales
# Inserted 6,060,000 rows into sales
# Inserted 6,070,000 rows into sales
# Inserted 6,080,000 rows into sales
# Inserted 6,090,000 rows into sales
# Inserted 6,100,000 rows into sales
# Inserted 6,110,000 rows into sales
# Inserted 6,120,000 rows into sales
# Inserted 6,130,000 rows into sales
# Inserted 6,140,000 rows into sales
# Inserted 6,150,000 rows into sales
# Inserted 6,160,000 rows into sales
# Inserted 6,170,000 rows into sales
# Inserted 6,180,000 rows into sales
# Inserted 6,190,000 rows into sales
# Inserted 6,200,000 rows into sales
# Inserted 6,210,000 rows into sales
# Inserted 6,220,000 rows into sales
# Inserted 6,230,000 rows into sales
# Inserted 6,240,000 rows into sales
# Inserted 6,250,000 rows into sales
# Inserted 6,260,000 rows into sales
# Inserted 6,270,000 rows into sales
# Inserted 6,280,000 rows into sales
# Inserted 6,290,000 rows into sales
# Inserted 6,300,000 rows into sales
# Inserted 6,310,000 rows into sales
# Inserted 6,320,000 rows into sales
# Inserted 6,330,000 rows into sales
# Inserted 6,340,000 rows into sales
# Inserted 6,350,000 rows into sales
# Inserted 6,360,000 rows into sales
# Inserted 6,370,000 rows into sales
# Inserted 6,380,000 rows into sales
# Inserted 6,390,000 rows into sales
# Inserted 6,400,000 rows into sales
# Inserted 6,410,000 rows into sales
# Inserted 6,420,000 rows into sales
# Inserted 6,430,000 rows into sales
# Inserted 6,440,000 rows into sales
# Inserted 6,450,000 rows into sales
# Inserted 6,460,000 rows into sales
# Inserted 6,470,000 rows into sales
# Inserted 6,480,000 rows into sales
# Inserted 6,490,000 rows into sales
# Inserted 6,500,000 rows into sales
# Inserted 6,510,000 rows into sales
# Inserted 6,520,000 rows into sales
# Inserted 6,530,000 rows into sales
# Inserted 6,540,000 rows into sales
# Inserted 6,550,000 rows into sales
# Inserted 6,560,000 rows into sales
# Inserted 6,570,000 rows into sales
# Inserted 6,580,000 rows into sales
# Inserted 6,590,000 rows into sales
# Inserted 6,600,000 rows into sales
# Inserted 6,610,000 rows into sales
# Inserted 6,620,000 rows into sales
# Inserted 6,630,000 rows into sales
# Inserted 6,640,000 rows into sales
# Inserted 6,650,000 rows into sales
# Inserted 6,660,000 rows into sales
# Inserted 6,670,000 rows into sales
# Inserted 6,680,000 rows into sales
# Inserted 6,690,000 rows into sales
# Inserted 6,700,000 rows into sales
# Inserted 6,710,000 rows into sales
# Inserted 6,720,000 rows into sales
# Inserted 6,730,000 rows into sales
# Inserted 6,740,000 rows into sales
# Inserted 6,750,000 rows into sales
# Inserted 6,760,000 rows into sales
# Inserted 6,770,000 rows into sales
# Inserted 6,780,000 rows into sales
# Inserted 6,790,000 rows into sales
# Inserted 6,800,000 rows into sales
# Inserted 6,810,000 rows into sales
# Inserted 6,820,000 rows into sales
# Inserted 6,830,000 rows into sales
# Inserted 6,840,000 rows into sales
# Inserted 6,850,000 rows into sales
# Inserted 6,860,000 rows into sales
# Inserted 6,870,000 rows into sales
# Inserted 6,880,000 rows into sales
# Inserted 6,890,000 rows into sales
# Inserted 6,900,000 rows into sales
# Inserted 6,910,000 rows into sales
# Inserted 6,920,000 rows into sales
# Inserted 6,930,000 rows into sales
# Inserted 6,940,000 rows into sales
# Inserted 6,950,000 rows into sales
# Inserted 6,960,000 rows into sales
# Inserted 6,970,000 rows into sales
# Inserted 6,980,000 rows into sales
# Inserted 6,990,000 rows into sales
# Inserted 7,000,000 rows into sales
# Inserted 7,010,000 rows into sales
# Inserted 7,020,000 rows into sales
# Inserted 7,030,000 rows into sales
# Inserted 7,040,000 rows into sales
# Inserted 7,050,000 rows into sales
# Inserted 7,060,000 rows into sales
# Inserted 7,070,000 rows into sales
# Inserted 7,080,000 rows into sales
# Inserted 7,090,000 rows into sales
# Inserted 7,100,000 rows into sales
# Inserted 7,110,000 rows into sales
# Inserted 7,120,000 rows into sales
# Inserted 7,130,000 rows into sales
# Inserted 7,140,000 rows into sales
# Inserted 7,150,000 rows into sales
# Inserted 7,160,000 rows into sales
# Inserted 7,170,000 rows into sales
# Inserted 7,180,000 rows into sales
# Inserted 7,190,000 rows into sales
# Inserted 7,200,000 rows into sales
# Inserted 7,210,000 rows into sales
# Inserted 7,220,000 rows into sales
# Inserted 7,230,000 rows into sales
# Inserted 7,240,000 rows into sales
# Inserted 7,250,000 rows into sales
# Inserted 7,260,000 rows into sales
# Inserted 7,270,000 rows into sales
# Inserted 7,280,000 rows into sales
# Inserted 7,290,000 rows into sales
# Inserted 7,300,000 rows into sales
# Inserted 7,310,000 rows into sales
# Inserted 7,320,000 rows into sales
# Inserted 7,330,000 rows into sales
# Inserted 7,340,000 rows into sales
# Inserted 7,350,000 rows into sales
# Inserted 7,360,000 rows into sales
# Inserted 7,370,000 rows into sales
# Inserted 7,380,000 rows into sales
# Inserted 7,390,000 rows into sales
# Inserted 7,400,000 rows into sales
# Inserted 7,410,000 rows into sales
# Inserted 7,420,000 rows into sales
# Inserted 7,430,000 rows into sales
# Inserted 7,440,000 rows into sales
# Inserted 7,450,000 rows into sales
# Inserted 7,460,000 rows into sales
# Inserted 7,470,000 rows into sales
# Inserted 7,480,000 rows into sales
# Inserted 7,490,000 rows into sales
# Inserted 7,500,000 rows into sales
# Inserted 7,510,000 rows into sales
# Inserted 7,520,000 rows into sales
# Inserted 7,530,000 rows into sales
# Inserted 7,540,000 rows into sales
# Inserted 7,550,000 rows into sales
# Inserted 7,560,000 rows into sales
# Inserted 7,570,000 rows into sales
# Inserted 7,580,000 rows into sales
# Inserted 7,590,000 rows into sales
# Inserted 7,600,000 rows into sales
# Inserted 7,610,000 rows into sales
# Inserted 7,620,000 rows into sales
# Inserted 7,630,000 rows into sales
# Inserted 7,640,000 rows into sales
# Inserted 7,650,000 rows into sales
# Inserted 7,660,000 rows into sales
# Inserted 7,670,000 rows into sales
# Inserted 7,680,000 rows into sales
# Inserted 7,690,000 rows into sales
# Inserted 7,700,000 rows into sales
# Inserted 7,710,000 rows into sales
# Inserted 7,720,000 rows into sales
# Inserted 7,730,000 rows into sales
# Inserted 7,740,000 rows into sales
# Inserted 7,750,000 rows into sales
# Inserted 7,760,000 rows into sales
# Inserted 7,770,000 rows into sales
# Inserted 7,780,000 rows into sales
# Inserted 7,790,000 rows into sales
# Inserted 7,800,000 rows into sales
# Inserted 7,810,000 rows into sales
# Inserted 7,820,000 rows into sales
# Inserted 7,830,000 rows into sales
# Inserted 7,840,000 rows into sales
# Inserted 7,850,000 rows into sales
# Inserted 7,860,000 rows into sales
# Inserted 7,870,000 rows into sales
# Inserted 7,880,000 rows into sales
# Inserted 7,890,000 rows into sales
# Inserted 7,900,000 rows into sales
# Inserted 7,910,000 rows into sales
# Inserted 7,920,000 rows into sales
# Inserted 7,930,000 rows into sales
# Inserted 7,940,000 rows into sales
# Inserted 7,950,000 rows into sales
# Inserted 7,960,000 rows into sales
# Inserted 7,970,000 rows into sales
# Inserted 7,980,000 rows into sales
# Inserted 7,990,000 rows into sales
# Inserted 8,000,000 rows into sales
# Inserted 8,010,000 rows into sales
# Inserted 8,020,000 rows into sales
# Inserted 8,030,000 rows into sales
# Inserted 8,040,000 rows into sales
# Inserted 8,050,000 rows into sales
# Inserted 8,060,000 rows into sales
# Inserted 8,070,000 rows into sales
# Inserted 8,080,000 rows into sales
# Inserted 8,090,000 rows into sales
# Inserted 8,100,000 rows into sales
# Inserted 8,110,000 rows into sales
# Inserted 8,120,000 rows into sales
# Inserted 8,130,000 rows into sales
# Inserted 8,140,000 rows into sales
# Inserted 8,150,000 rows into sales
# Inserted 8,160,000 rows into sales
# Inserted 8,170,000 rows into sales
# Inserted 8,180,000 rows into sales
# Inserted 8,190,000 rows into sales
# Inserted 8,200,000 rows into sales
# Inserted 8,210,000 rows into sales
# Inserted 8,220,000 rows into sales
# Inserted 8,230,000 rows into sales
# Inserted 8,240,000 rows into sales
# Inserted 8,250,000 rows into sales
# Inserted 8,260,000 rows into sales
# Inserted 8,270,000 rows into sales
# Inserted 8,280,000 rows into sales
# Inserted 8,290,000 rows into sales
# Inserted 8,300,000 rows into sales
# Inserted 8,310,000 rows into sales
# Inserted 8,320,000 rows into sales
# Inserted 8,330,000 rows into sales
# Inserted 8,340,000 rows into sales
# Inserted 8,350,000 rows into sales
# Inserted 8,360,000 rows into sales
# Inserted 8,370,000 rows into sales
# Inserted 8,380,000 rows into sales
# Inserted 8,390,000 rows into sales
# Inserted 8,400,000 rows into sales
# Inserted 8,410,000 rows into sales
# Inserted 8,420,000 rows into sales
# Inserted 8,430,000 rows into sales
# Inserted 8,440,000 rows into sales
# Inserted 8,450,000 rows into sales
# Inserted 8,460,000 rows into sales
# Inserted 8,470,000 rows into sales
# Inserted 8,480,000 rows into sales
# Inserted 8,490,000 rows into sales
# Inserted 8,500,000 rows into sales
# Inserted 8,510,000 rows into sales
# Inserted 8,520,000 rows into sales
# Inserted 8,530,000 rows into sales
# Inserted 8,540,000 rows into sales
# Inserted 8,550,000 rows into sales
# Inserted 8,560,000 rows into sales
# Inserted 8,570,000 rows into sales
# Inserted 8,580,000 rows into sales
# Inserted 8,590,000 rows into sales
# Inserted 8,600,000 rows into sales
# Inserted 8,610,000 rows into sales
# Inserted 8,620,000 rows into sales
# Inserted 8,630,000 rows into sales
# Inserted 8,640,000 rows into sales
# Inserted 8,650,000 rows into sales
# Inserted 8,660,000 rows into sales
# Inserted 8,670,000 rows into sales
# Inserted 8,680,000 rows into sales
# Inserted 8,690,000 rows into sales
# Inserted 8,700,000 rows into sales
# Inserted 8,710,000 rows into sales
# Inserted 8,720,000 rows into sales
# Inserted 8,730,000 rows into sales
# Inserted 8,740,000 rows into sales
# Inserted 8,750,000 rows into sales
# Inserted 8,760,000 rows into sales
# Inserted 8,770,000 rows into sales
# Inserted 8,780,000 rows into sales
# Inserted 8,790,000 rows into sales
# Inserted 8,800,000 rows into sales
# Inserted 8,810,000 rows into sales
# Inserted 8,820,000 rows into sales
# Inserted 8,830,000 rows into sales
# Inserted 8,840,000 rows into sales
# Inserted 8,850,000 rows into sales
# Inserted 8,860,000 rows into sales
# Inserted 8,870,000 rows into sales
# Inserted 8,880,000 rows into sales
# Inserted 8,890,000 rows into sales
# Inserted 8,900,000 rows into sales
# Inserted 8,910,000 rows into sales
# Inserted 8,920,000 rows into sales
# Inserted 8,930,000 rows into sales
# Inserted 8,940,000 rows into sales
# Inserted 8,950,000 rows into sales
# Inserted 8,960,000 rows into sales
# Inserted 8,970,000 rows into sales
# Inserted 8,980,000 rows into sales
# Inserted 8,990,000 rows into sales
# Inserted 9,000,000 rows into sales
# Inserted 9,010,000 rows into sales
# Inserted 9,020,000 rows into sales
# Inserted 9,030,000 rows into sales
# Inserted 9,040,000 rows into sales
# Inserted 9,050,000 rows into sales
# Inserted 9,060,000 rows into sales
# Inserted 9,070,000 rows into sales
# Inserted 9,080,000 rows into sales
# Inserted 9,090,000 rows into sales
# Inserted 9,100,000 rows into sales
# Inserted 9,110,000 rows into sales
# Inserted 9,120,000 rows into sales
# Inserted 9,130,000 rows into sales
# Inserted 9,140,000 rows into sales
# Inserted 9,150,000 rows into sales
# Inserted 9,160,000 rows into sales
# Inserted 9,170,000 rows into sales
# Inserted 9,180,000 rows into sales
# Inserted 9,190,000 rows into sales
# Inserted 9,200,000 rows into sales
# Inserted 9,210,000 rows into sales
# Inserted 9,220,000 rows into sales
# Inserted 9,230,000 rows into sales
# Inserted 9,240,000 rows into sales
# Inserted 9,250,000 rows into sales
# Inserted 9,260,000 rows into sales
# Inserted 9,270,000 rows into sales
# Inserted 9,280,000 rows into sales
# Inserted 9,290,000 rows into sales
# Inserted 9,300,000 rows into sales
# Inserted 9,310,000 rows into sales
# Inserted 9,320,000 rows into sales
# Inserted 9,330,000 rows into sales
# Inserted 9,340,000 rows into sales
# Inserted 9,350,000 rows into sales
# Inserted 9,360,000 rows into sales
# Inserted 9,370,000 rows into sales
# Inserted 9,380,000 rows into sales
# Inserted 9,390,000 rows into sales
# Inserted 9,400,000 rows into sales
# Inserted 9,410,000 rows into sales
# Inserted 9,420,000 rows into sales
# Inserted 9,430,000 rows into sales
# Inserted 9,440,000 rows into sales
# Inserted 9,450,000 rows into sales
# Inserted 9,460,000 rows into sales
# Inserted 9,470,000 rows into sales
# Inserted 9,480,000 rows into sales
# Inserted 9,490,000 rows into sales
# Inserted 9,500,000 rows into sales
# Inserted 9,510,000 rows into sales
# Inserted 9,520,000 rows into sales
# Inserted 9,530,000 rows into sales
# Inserted 9,540,000 rows into sales
# Inserted 9,550,000 rows into sales
# Inserted 9,560,000 rows into sales
# Inserted 9,570,000 rows into sales
# Inserted 9,580,000 rows into sales
# Inserted 9,590,000 rows into sales
# Inserted 9,600,000 rows into sales
# Inserted 9,610,000 rows into sales
# Inserted 9,620,000 rows into sales
# Inserted 9,630,000 rows into sales
# Inserted 9,640,000 rows into sales
# Inserted 9,650,000 rows into sales
# Inserted 9,660,000 rows into sales
# Inserted 9,670,000 rows into sales
# Inserted 9,680,000 rows into sales
# Inserted 9,690,000 rows into sales
# Inserted 9,700,000 rows into sales
# Inserted 9,710,000 rows into sales
# Inserted 9,720,000 rows into sales
# Inserted 9,730,000 rows into sales
# Inserted 9,740,000 rows into sales
# Inserted 9,750,000 rows into sales
# Inserted 9,760,000 rows into sales
# Inserted 9,770,000 rows into sales
# Inserted 9,780,000 rows into sales
# Inserted 9,790,000 rows into sales
# Inserted 9,800,000 rows into sales
# Inserted 9,810,000 rows into sales
# Inserted 9,820,000 rows into sales
# Inserted 9,830,000 rows into sales
# Inserted 9,840,000 rows into sales
# Inserted 9,850,000 rows into sales
# Inserted 9,860,000 rows into sales
# Inserted 9,870,000 rows into sales
# Inserted 9,880,000 rows into sales
# Inserted 9,890,000 rows into sales
# Inserted 9,900,000 rows into sales
# Inserted 9,910,000 rows into sales
# Inserted 9,920,000 rows into sales
# Inserted 9,930,000 rows into sales
# Inserted 9,940,000 rows into sales
# Inserted 9,950,000 rows into sales
# Inserted 9,960,000 rows into sales
# Inserted 9,970,000 rows into sales
# Inserted 9,980,000 rows into sales
# Inserted 9,990,000 rows into sales
# Inserted 10,000,000 rows into sales
# Inserted 10,010,000 rows into sales
# Inserted 10,020,000 rows into sales
# Inserted 10,030,000 rows into sales
# Inserted 10,040,000 rows into sales
# Inserted 10,050,000 rows into sales
# Inserted 10,060,000 rows into sales
# Inserted 10,070,000 rows into sales
# Inserted 10,080,000 rows into sales
# Inserted 10,090,000 rows into sales
# Inserted 10,100,000 rows into sales
# Inserted 10,110,000 rows into sales
# Inserted 10,120,000 rows into sales
# Inserted 10,130,000 rows into sales
# Inserted 10,140,000 rows into sales
# Inserted 10,150,000 rows into sales
# Inserted 10,160,000 rows into sales
# Inserted 10,170,000 rows into sales
# Inserted 10,180,000 rows into sales
# Inserted 10,190,000 rows into sales
# Inserted 10,200,000 rows into sales
# Inserted 10,210,000 rows into sales
# Inserted 10,220,000 rows into sales
# Inserted 10,230,000 rows into sales
# Inserted 10,240,000 rows into sales
# Inserted 10,250,000 rows into sales
# Inserted 10,260,000 rows into sales
# Inserted 10,270,000 rows into sales
# Inserted 10,280,000 rows into sales
# Inserted 10,290,000 rows into sales
# Inserted 10,300,000 rows into sales
# Inserted 10,310,000 rows into sales
# Inserted 10,320,000 rows into sales
# Inserted 10,330,000 rows into sales
# Inserted 10,340,000 rows into sales
# Inserted 10,350,000 rows into sales
# Inserted 10,360,000 rows into sales
# Inserted 10,370,000 rows into sales
# Inserted 10,380,000 rows into sales
# Inserted 10,390,000 rows into sales
# Inserted 10,400,000 rows into sales
# Inserted 10,410,000 rows into sales
# Inserted 10,420,000 rows into sales
# Inserted 10,430,000 rows into sales
# Inserted 10,440,000 rows into sales
# Inserted 10,450,000 rows into sales
# Inserted 10,460,000 rows into sales
# Inserted 10,470,000 rows into sales
# Inserted 10,480,000 rows into sales
# Inserted 10,490,000 rows into sales
# Inserted 10,500,000 rows into sales
# Inserted 10,510,000 rows into sales
# Inserted 10,520,000 rows into sales
# Inserted 10,530,000 rows into sales
# Inserted 10,540,000 rows into sales
# Inserted 10,550,000 rows into sales
# Inserted 10,560,000 rows into sales
# Inserted 10,570,000 rows into sales
# Inserted 10,580,000 rows into sales
# Inserted 10,590,000 rows into sales
# Inserted 10,600,000 rows into sales
# Inserted 10,610,000 rows into sales
# Inserted 10,620,000 rows into sales
# Inserted 10,630,000 rows into sales
# Inserted 10,640,000 rows into sales
# Inserted 10,650,000 rows into sales
# Inserted 10,660,000 rows into sales
# Inserted 10,670,000 rows into sales
# Inserted 10,680,000 rows into sales
# Inserted 10,690,000 rows into sales
# Inserted 10,700,000 rows into sales
# Inserted 10,710,000 rows into sales
# Inserted 10,720,000 rows into sales
# Inserted 10,730,000 rows into sales
# Inserted 10,740,000 rows into sales
# Inserted 10,750,000 rows into sales
# Inserted 10,760,000 rows into sales
# Inserted 10,770,000 rows into sales
# Inserted 10,780,000 rows into sales
# Inserted 10,790,000 rows into sales
# Inserted 10,800,000 rows into sales
# Inserted 10,810,000 rows into sales
# Inserted 10,820,000 rows into sales
# Inserted 10,830,000 rows into sales
# Inserted 10,840,000 rows into sales
# Inserted 10,850,000 rows into sales
# Inserted 10,860,000 rows into sales
# Inserted 10,870,000 rows into sales
# Inserted 10,880,000 rows into sales
# Inserted 10,890,000 rows into sales
# Inserted 10,900,000 rows into sales
# Inserted 10,910,000 rows into sales
# Inserted 10,920,000 rows into sales
# Inserted 10,930,000 rows into sales
# Inserted 10,940,000 rows into sales
# Inserted 10,950,000 rows into sales
# Inserted 10,960,000 rows into sales
# Inserted 10,970,000 rows into sales
# Inserted 10,980,000 rows into sales
# Inserted 10,990,000 rows into sales
# Inserted 11,000,000 rows into sales
# Inserted 11,010,000 rows into sales
# Inserted 11,020,000 rows into sales
# Inserted 11,030,000 rows into sales
# Inserted 11,040,000 rows into sales
# Inserted 11,050,000 rows into sales
# Inserted 11,060,000 rows into sales
# Inserted 11,070,000 rows into sales
# Inserted 11,080,000 rows into sales
# Inserted 11,090,000 rows into sales
# Inserted 11,100,000 rows into sales
# Inserted 11,110,000 rows into sales
# Inserted 11,120,000 rows into sales
# Inserted 11,130,000 rows into sales
# Inserted 11,140,000 rows into sales
# Inserted 11,150,000 rows into sales
# Inserted 11,160,000 rows into sales
# Inserted 11,170,000 rows into sales
# Inserted 11,180,000 rows into sales
# Inserted 11,190,000 rows into sales
# Inserted 11,200,000 rows into sales
# Inserted 11,210,000 rows into sales
# Inserted 11,220,000 rows into sales
# Inserted 11,230,000 rows into sales
# Inserted 11,240,000 rows into sales
# Inserted 11,250,000 rows into sales
# Inserted 11,260,000 rows into sales
# Inserted 11,270,000 rows into sales
# Inserted 11,280,000 rows into sales
# Inserted 11,290,000 rows into sales
# Inserted 11,300,000 rows into sales
# Inserted 11,310,000 rows into sales
# Inserted 11,320,000 rows into sales
# Inserted 11,330,000 rows into sales
# Inserted 11,340,000 rows into sales
# Inserted 11,350,000 rows into sales
# Inserted 11,360,000 rows into sales
# Inserted 11,370,000 rows into sales
# Inserted 11,380,000 rows into sales
# Inserted 11,390,000 rows into sales
# Inserted 11,400,000 rows into sales
# Inserted 11,410,000 rows into sales
# Inserted 11,420,000 rows into sales
# Inserted 11,430,000 rows into sales
# Inserted 11,440,000 rows into sales
# Inserted 11,450,000 rows into sales
# Inserted 11,460,000 rows into sales
# Inserted 11,470,000 rows into sales
# Inserted 11,480,000 rows into sales
# Inserted 11,490,000 rows into sales
# Inserted 11,500,000 rows into sales
# Inserted 11,510,000 rows into sales
# Inserted 11,520,000 rows into sales
# Inserted 11,530,000 rows into sales
# Inserted 11,540,000 rows into sales
# Inserted 11,550,000 rows into sales
# Inserted 11,560,000 rows into sales
# Inserted 11,570,000 rows into sales
# Inserted 11,580,000 rows into sales
# Inserted 11,590,000 rows into sales
# Inserted 11,600,000 rows into sales
# Inserted 11,610,000 rows into sales
# Inserted 11,620,000 rows into sales
# Inserted 11,630,000 rows into sales
# Inserted 11,640,000 rows into sales
# Inserted 11,650,000 rows into sales
# Inserted 11,660,000 rows into sales
# Inserted 11,670,000 rows into sales
# Inserted 11,680,000 rows into sales
# Inserted 11,690,000 rows into sales
# Inserted 11,700,000 rows into sales
# Inserted 11,710,000 rows into sales
# Inserted 11,720,000 rows into sales
# Inserted 11,730,000 rows into sales
# Inserted 11,740,000 rows into sales
# Inserted 11,750,000 rows into sales
# Inserted 11,760,000 rows into sales
# Inserted 11,770,000 rows into sales
# Inserted 11,780,000 rows into sales
# Inserted 11,790,000 rows into sales
# Inserted 11,800,000 rows into sales
# Inserted 11,810,000 rows into sales
# Inserted 11,820,000 rows into sales
# Inserted 11,830,000 rows into sales
# Inserted 11,840,000 rows into sales
# Inserted 11,850,000 rows into sales
# Inserted 11,860,000 rows into sales
# Inserted 11,870,000 rows into sales
# Inserted 11,880,000 rows into sales
# Inserted 11,890,000 rows into sales
# Inserted 11,900,000 rows into sales
# Inserted 11,910,000 rows into sales
# Inserted 11,920,000 rows into sales
# Inserted 11,930,000 rows into sales
# Inserted 11,940,000 rows into sales
# Inserted 11,950,000 rows into sales
# Inserted 11,960,000 rows into sales
# Inserted 11,970,000 rows into sales
# Inserted 11,980,000 rows into sales
# Inserted 11,990,000 rows into sales
# Inserted 12,000,000 rows into sales
# Inserted 12,010,000 rows into sales
# Inserted 12,020,000 rows into sales
# Inserted 12,030,000 rows into sales
# Inserted 12,040,000 rows into sales
# Inserted 12,050,000 rows into sales
# Inserted 12,060,000 rows into sales
# Inserted 12,070,000 rows into sales
# Inserted 12,080,000 rows into sales
# Inserted 12,090,000 rows into sales
# Inserted 12,100,000 rows into sales
# Inserted 12,110,000 rows into sales
# Inserted 12,120,000 rows into sales
# Inserted 12,130,000 rows into sales
# Inserted 12,140,000 rows into sales
# Inserted 12,150,000 rows into sales
# Inserted 12,160,000 rows into sales
# Inserted 12,170,000 rows into sales
# Inserted 12,180,000 rows into sales
# Inserted 12,190,000 rows into sales
# Inserted 12,200,000 rows into sales
# Inserted 12,210,000 rows into sales
# Inserted 12,220,000 rows into sales
# Inserted 12,230,000 rows into sales
# Inserted 12,240,000 rows into sales
# Inserted 12,250,000 rows into sales
# Inserted 12,260,000 rows into sales
# Inserted 12,270,000 rows into sales
# Inserted 12,280,000 rows into sales
# Inserted 12,290,000 rows into sales
# Inserted 12,300,000 rows into sales
# Inserted 12,310,000 rows into sales
# Inserted 12,320,000 rows into sales
# Inserted 12,330,000 rows into sales
# Inserted 12,340,000 rows into sales
# Inserted 12,350,000 rows into sales
# Inserted 12,360,000 rows into sales
# Inserted 12,370,000 rows into sales
# Inserted 12,380,000 rows into sales
# Inserted 12,390,000 rows into sales
# Inserted 12,400,000 rows into sales
# Inserted 12,410,000 rows into sales
# Inserted 12,420,000 rows into sales
# Inserted 12,430,000 rows into sales
# Inserted 12,440,000 rows into sales
# Inserted 12,450,000 rows into sales
# Inserted 12,460,000 rows into sales
# Inserted 12,470,000 rows into sales
# Inserted 12,480,000 rows into sales
# Inserted 12,490,000 rows into sales
# Inserted 12,500,000 rows into sales
# Inserted 12,510,000 rows into sales
# Inserted 12,520,000 rows into sales
# Inserted 12,530,000 rows into sales
# Inserted 12,540,000 rows into sales
# Inserted 12,550,000 rows into sales
# Inserted 12,560,000 rows into sales
# Inserted 12,570,000 rows into sales
# Inserted 12,580,000 rows into sales
# Inserted 12,590,000 rows into sales
# Inserted 12,600,000 rows into sales
# Inserted 12,610,000 rows into sales
# Inserted 12,620,000 rows into sales
# Inserted 12,630,000 rows into sales
# Inserted 12,640,000 rows into sales
# Inserted 12,650,000 rows into sales
# Inserted 12,660,000 rows into sales
# Inserted 12,670,000 rows into sales
# Inserted 12,680,000 rows into sales
# Inserted 12,690,000 rows into sales
# Inserted 12,700,000 rows into sales
# Inserted 12,710,000 rows into sales
# Inserted 12,720,000 rows into sales
# Inserted 12,730,000 rows into sales
# Inserted 12,740,000 rows into sales
# Inserted 12,750,000 rows into sales
# Inserted 12,760,000 rows into sales
# Inserted 12,770,000 rows into sales
# Inserted 12,780,000 rows into sales
# Inserted 12,790,000 rows into sales
# Inserted 12,800,000 rows into sales
# Inserted 12,810,000 rows into sales
# Inserted 12,820,000 rows into sales
# Inserted 12,825,363 rows into sales
# Finished sales
#
# Processing vendor_invoice.csv
# Inserted 5,543 rows into vendor_invoice
# Finished vendor_invoice

# %%
# Out:
# '.ipynb_checkpoints'
# 'analysis.ipynb'
# 'begin_inventory.csv'
# 'end_inventory.csv'
# 'purchases.csv'
# 'purchase_prices.csv'
# 'sales.csv'
# 'vendor_invoice.csv'

# %%
# Out:
# ['begin_inventory', 'end_inventory', 'purchase_prices', 'purchases', 'sales', 'vendor_invoice']

# %%
# Out:
# begin_inventory      206,529 rows
# end_inventory        224,489 rows
# purchase_prices      12,261 rows
# purchases            2,372,474 rows
# sales                12,825,363 rows
# vendor_invoice       5,543 rows

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\ASUS\Downloads\data\data

# %%
import os
import time
import logging
import pandas as pd
from sqlalchemy import create_engine

# ==========================================
# Create Logs Folder (if it doesn't exist)
# ==========================================
os.makedirs("../logs", exist_ok=True)

# ==========================================
# Logging Configuration
# ==========================================
logging.basicConfig(
    filename="../logs/ingestion_db.log",
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

# ==========================================
# Database Connection
# ==========================================
engine = create_engine("sqlite:///inventory.db")

# ==========================================
# Function to Ingest Data into SQLite
# ==========================================
def ingest_db(df, table_name, engine, mode):
    df.to_sql(
        name=table_name,
        con=engine,
        if_exists=mode,
        index=False
    )

# ==========================================
# Load All CSV Files
# ==========================================
def load_raw_data():

    start_time = time.time()

    CHUNK_SIZE = 10000

    logging.info("=" * 60)
    logging.info("Data Ingestion Started")

    for file in os.listdir():

        if file.endswith(".csv"):

            table_name = os.path.splitext(file)[0]

            print(f"\nProcessing {file}")
            logging.info(f"Started processing {file}")

            first_chunk = True
            total_rows = 0

            for chunk in pd.read_csv(file, chunksize=CHUNK_SIZE):

                ingest_db(
                    chunk,
                    table_name,
                    engine,
                    "replace" if first_chunk else "append"
                )

                total_rows += len(chunk)

                if total_rows % 100000 == 0 or first_chunk:
                    print(f"Inserted {total_rows:,} rows into {table_name}")

                first_chunk = False

            print(f"Finished {table_name}")

            logging.info(
                f"{table_name} imported successfully | Total Rows: {total_rows:,}"
            )

    end_time = time.time()

    total_time = (end_time - start_time) / 60

    print(f"\nTotal Time Taken : {total_time:.2f} Minutes")

    logging.info("=" * 60)
    logging.info("Data Ingestion Completed Successfully")
    logging.info(f"Total Time Taken : {total_time:.2f} Minutes")
    logging.info("=" * 60)


if __name__ == "__main__":
    load_raw_data()
# Out:
# Processing begin_inventory.csv
# Inserted 10,000 rows into begin_inventory
# Inserted 100,000 rows into begin_inventory
# Inserted 200,000 rows into begin_inventory
# Finished begin_inventory
#
# Processing end_inventory.csv
# Inserted 10,000 rows into end_inventory
# Inserted 100,000 rows into end_inventory
# Inserted 200,000 rows into end_inventory
# Finished end_inventory
#
# Processing purchases.csv
# Inserted 10,000 rows into purchases
# Inserted 100,000 rows into purchases
# Inserted 200,000 rows into purchases
# Inserted 300,000 rows into purchases
# Inserted 400,000 rows into purchases
# Inserted 500,000 rows into purchases
# Inserted 600,000 rows into purchases
# Inserted 700,000 rows into purchases
# Inserted 800,000 rows into purchases
# Inserted 900,000 rows into purchases
# Inserted 1,000,000 rows into purchases
# Inserted 1,100,000 rows into purchases
# Inserted 1,200,000 rows into purchases
# Inserted 1,300,000 rows into purchases
# Inserted 1,400,000 rows into purchases
# Inserted 1,500,000 rows into purchases
# Inserted 1,600,000 rows into purchases
# Inserted 1,700,000 rows into purchases
# Inserted 1,800,000 rows into purchases
# Inserted 1,900,000 rows into purchases
# Inserted 2,000,000 rows into purchases
# Inserted 2,100,000 rows into purchases
# Inserted 2,200,000 rows into purchases
# Inserted 2,300,000 rows into purchases
# Finished purchases
#
# Processing purchase_prices.csv
# Inserted 10,000 rows into purchase_prices
# Finished purchase_prices
#
# Processing sales.csv
# Inserted 10,000 rows into sales
# Inserted 100,000 rows into sales
# Inserted 200,000 rows into sales
# Inserted 300,000 rows into sales
# Inserted 400,000 rows into sales
# Inserted 500,000 rows into sales
# Inserted 600,000 rows into sales
# Inserted 700,000 rows into sales
# Inserted 800,000 rows into sales
# Inserted 900,000 rows into sales
# Inserted 1,000,000 rows into sales
# Inserted 1,100,000 rows into sales
# Inserted 1,200,000 rows into sales
# Inserted 1,300,000 rows into sales
# Inserted 1,400,000 rows into sales
# Inserted 1,500,000 rows into sales
# Inserted 1,600,000 rows into sales
# Inserted 1,700,000 rows into sales
# Inserted 1,800,000 rows into sales
# Inserted 1,900,000 rows into sales
# Inserted 2,000,000 rows into sales
# Inserted 2,100,000 rows into sales
# Inserted 2,200,000 rows into sales
# Inserted 2,300,000 rows into sales
# Inserted 2,400,000 rows into sales
# Inserted 2,500,000 rows into sales
# Inserted 2,600,000 rows into sales
# Inserted 2,700,000 rows into sales
# Inserted 2,800,000 rows into sales
# Inserted 2,900,000 rows into sales
# Inserted 3,000,000 rows into sales
# Inserted 3,100,000 rows into sales
# Inserted 3,200,000 rows into sales
# Inserted 3,300,000 rows into sales
# Inserted 3,400,000 rows into sales
# Inserted 3,500,000 rows into sales
# Inserted 3,600,000 rows into sales
# Inserted 3,700,000 rows into sales
# Inserted 3,800,000 rows into sales
# Inserted 3,900,000 rows into sales
# Inserted 4,000,000 rows into sales
# Inserted 4,100,000 rows into sales
# Inserted 4,200,000 rows into sales
# Inserted 4,300,000 rows into sales
# Inserted 4,400,000 rows into sales
# Inserted 4,500,000 rows into sales
# Inserted 4,600,000 rows into sales
# Inserted 4,700,000 rows into sales
# Inserted 4,800,000 rows into sales
# Inserted 4,900,000 rows into sales
# Inserted 5,000,000 rows into sales
# Inserted 5,100,000 rows into sales
# Inserted 5,200,000 rows into sales
# Inserted 5,300,000 rows into sales
# Inserted 5,400,000 rows into sales
# Inserted 5,500,000 rows into sales
# Inserted 5,600,000 rows into sales
# Inserted 5,700,000 rows into sales
# Inserted 5,800,000 rows into sales
# Inserted 5,900,000 rows into sales
# Inserted 6,000,000 rows into sales
# Inserted 6,100,000 rows into sales
# Inserted 6,200,000 rows into sales
# Inserted 6,300,000 rows into sales
# Inserted 6,400,000 rows into sales
# Inserted 6,500,000 rows into sales
# Inserted 6,600,000 rows into sales
# Inserted 6,700,000 rows into sales
# Inserted 6,800,000 rows into sales
# Inserted 6,900,000 rows into sales
# Inserted 7,000,000 rows into sales
# Inserted 7,100,000 rows into sales
# Inserted 7,200,000 rows into sales
# Inserted 7,300,000 rows into sales
# Inserted 7,400,000 rows into sales
# Inserted 7,500,000 rows into sales
# Inserted 7,600,000 rows into sales
# Inserted 7,700,000 rows into sales
# Inserted 7,800,000 rows into sales
# Inserted 7,900,000 rows into sales
# Inserted 8,000,000 rows into sales
# Inserted 8,100,000 rows into sales
# Inserted 8,200,000 rows into sales
# Inserted 8,300,000 rows into sales
# Inserted 8,400,000 rows into sales
# Inserted 8,500,000 rows into sales
# Inserted 8,600,000 rows into sales
# Inserted 8,700,000 rows into sales
# Inserted 8,800,000 rows into sales
# Inserted 8,900,000 rows into sales
# Inserted 9,000,000 rows into sales
# Inserted 9,100,000 rows into sales
# Inserted 9,200,000 rows into sales
# Inserted 9,300,000 rows into sales
# Inserted 9,400,000 rows into sales
# Inserted 9,500,000 rows into sales
# Inserted 9,600,000 rows into sales
# Inserted 9,700,000 rows into sales
# Inserted 9,800,000 rows into sales
# Inserted 9,900,000 rows into sales
# Inserted 10,000,000 rows into sales
# Inserted 10,100,000 rows into sales
# Inserted 10,200,000 rows into sales
# Inserted 10,300,000 rows into sales
# Inserted 10,400,000 rows into sales
# Inserted 10,500,000 rows into sales
# Inserted 10,600,000 rows into sales
# Inserted 10,700,000 rows into sales
# Inserted 10,800,000 rows into sales
# Inserted 10,900,000 rows into sales
# Inserted 11,000,000 rows into sales
# Inserted 11,100,000 rows into sales
# Inserted 11,200,000 rows into sales
# Inserted 11,300,000 rows into sales
# Inserted 11,400,000 rows into sales
# Inserted 11,500,000 rows into sales
# Inserted 11,600,000 rows into sales
# Inserted 11,700,000 rows into sales
# Inserted 11,800,000 rows into sales
# Inserted 11,900,000 rows into sales
# Inserted 12,000,000 rows into sales
# Inserted 12,100,000 rows into sales
# Inserted 12,200,000 rows into sales
# Inserted 12,300,000 rows into sales
# Inserted 12,400,000 rows into sales
# Inserted 12,500,000 rows into sales
# Inserted 12,600,000 rows into sales
# Inserted 12,700,000 rows into sales
# Inserted 12,800,000 rows into sales
# Finished sales
#
# Processing vendor_invoice.csv
# Inserted 5,543 rows into vendor_invoice
# Finished vendor_invoice
#
# Total Time Taken : 4.25 Minutes
